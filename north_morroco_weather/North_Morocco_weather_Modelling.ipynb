# %%
import pandas as pd

# %%
df=pd.read_csv('morroco_weather.csv',low_memory=False,index_col='DATE')

# %%
df.head()
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 1990-01-31  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.06
# 1990-02-01  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-02  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-03  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-04  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
#
#            PRCP_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX  \
# DATE
# 1990-01-31             ,,E   NaN             NaN  60.0            H,,S  69.0
# 1990-02-01             ,,E   NaN             NaN  58.0            H,,S  62.0
# 1990-02-02             ,,E   NaN             NaN  59.0            H,,S  65.0
# 1990-02-03             ,,E   NaN             NaN  60.0            H,,S  64.0
# 1990-02-04             ,,E   NaN             NaN  58.0            H,,S  64.0
#
# ...

# %%
df['TMAX_CEL']=(df['TMAX']-31)*5/9
df['TMIN_CEL']=(df['TMIN']-31)*5/9

# %%
df_Mellilia = df[df['NAME']=='MELILLA, SP']

# %%
df.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES', 'TAVG', 'TAVG_ATTRIBUTES',
#        'TMAX', 'TMAX_ATTRIBUTES', 'TMIN', 'TMIN_ATTRIBUTES'],
#       dtype='object')

# %%
df_Mellilia
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 1990-01-31  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.06
# 1990-02-01  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-02  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-03  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-04  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# ...                 ...          ...       ...        ...        ...   ...
# 2024-10-13  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.31
# 2024-10-14  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 2024-10-15  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.03
# 2024-10-16  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.02
# 2024-10-17  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.08
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load data
data = pd.read_csv('weather_data.csv', index_col='date', parse_dates=True)

# Check for missing values
print(data.isnull().sum())

# Fill missing values (impute with mean for simplicity, but you could use other methods)
data.fillna(data.mean(), inplace=True)

# Normalize numerical features
scaler = MinMaxScaler()
data[['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'SNWD', 'TAVG', 'TMAX', 'TMIN']] = scaler.fit_transform(
    data[['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'SNWD', 'TAVG', 'TMAX', 'TMIN']]
)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
print(df_Mellilia .isnull().sum())
# Out:
# STATION                0
# NAME                   0
# LATITUDE               0
# LONGITUDE              0
# ELEVATION              0
# PRCP                   2
# PRCP_ATTRIBUTES        2
# SNWD               12679
# SNWD_ATTRIBUTES    12679
# TAVG                  22
# TAVG_ATTRIBUTES       22
# TMAX                  60
# TMAX_ATTRIBUTES       60
# TMIN                  44
# TMIN_ATTRIBUTES       44
# dtype: int64

# %%
df_Mellilia = df_Mellilia .drop(columns=['PRCP_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES', 'TAVG_ATTRIBUTES', 'TMAX_ATTRIBUTES', 'TMIN_ATTRIBUTES'])

# %%
df_Mellilia
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 1990-01-31  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.06
# 1990-02-01  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-02  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-03  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 1990-02-04  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# ...                 ...          ...       ...        ...        ...   ...
# 2024-10-13  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.31
# 2024-10-14  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.00
# 2024-10-15  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.03
# 2024-10-16  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.02
# 2024-10-17  SP000060338  MELILLA, SP   35.2778    -2.9553       47.0  0.08
#
#             TAVG  TMAX  TMIN
# DATE
# ...

# %%
# Fill missing values in all specified columns with their means in one step
df_Mellilia [['PRCP', 'TAVG', 'TMAX', 'TMIN']] = df_Mellilia [['PRCP', 'TAVG', 'TMAX', 'TMIN']].apply(lambda x: x.fillna(x.mean()))

# %%
print(df_Mellilia .isnull().sum())
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# PRCP         0
# TAVG         0
# TMAX         0
# TMIN         0
# dtype: int64

# %%
df_Mellilia .columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG',
#        'TMAX', 'TMIN'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
df_Mellilia [['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN']] = scaler.fit_transform(
    df_Mellilia [['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN']]
)

# %%
df_Mellilia['LONGITUDE'].sum()
# Out:
# 0.0

# %%
df_Mellilia .index = pd.to_datetime(df_Mellilia .index)
df_Mellilia ['month'] = df_Mellilia .index.month
df_Mellilia ['season'] = df_Mellilia .index.month % 12 // 3 + 1  # Simple way to assign seasons

# %%
df_Mellilia .head()
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 1990-01-31  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-01  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-02  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-03  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-04  SP000060338  MELILLA, SP       0.0        0.0        0.0
#
#                 PRCP      TAVG      TMAX      TMIN  month  season
# DATE
# 1990-01-31  0.013129  0.389831  0.387097  0.321429      1       1
# 1990-02-01  0.000000  0.355932  0.274194  0.321429      2       1
# 1990-02-02  0.000000  0.372881  0.322581  0.375000      2       1
# 1990-02-03  0.000000  0.389831  0.306452  0.357143      2       1
# 1990-02-04  0.000000  0.355932  0.306452  0.303571      2       1

# %%
df_Mellilia = df_Mellilia .sort_index(ascending=True)

# %%
df_Mellilia
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 1990-01-31  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-01  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-02  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-03  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-02-04  SP000060338  MELILLA, SP       0.0        0.0        0.0
# ...                 ...          ...       ...        ...        ...
# 2024-10-13  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-14  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-15  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-16  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-17  SP000060338  MELILLA, SP       0.0        0.0        0.0
#
#                 PRCP      TAVG      TMAX      TMIN  month  season
# DATE
# ...

# %%
# Moving averages (e.g., 7-day moving average for TAVG)
df_Mellilia ['TAVG_MA7'] = df_Mellilia ['TAVG'].rolling(window=7).mean()
df_Mellilia ['TAVG_MA30'] = df_Mellilia ['TAVG'].rolling(window=30).mean()

# Drop rows with NaN values after rolling operation

# %%
df_Mellilia.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG',
#        'TMAX', 'TMIN', 'month', 'season', 'TAVG_MA7', 'TAVG_MA30'],
#       dtype='object')

# %%
df_Mellilia.dropna(inplace=True)

# %%
df_Mellilia
# Out:
#                 STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 1990-03-01  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-03-02  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-03-03  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-03-04  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 1990-03-05  SP000060338  MELILLA, SP       0.0        0.0        0.0
# ...                 ...          ...       ...        ...        ...
# 2024-10-13  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-14  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-15  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-16  SP000060338  MELILLA, SP       0.0        0.0        0.0
# 2024-10-17  SP000060338  MELILLA, SP       0.0        0.0        0.0
#
#                 PRCP      TAVG      TMAX      TMIN  month  season  TAVG_MA7  \
# DATE
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Temperature trend over time
plt.figure(figsize=(12, 6))
plt.plot(df_Mellilia.index, df_Mellilia['TAVG'], label='Average Temperature')
plt.plot(df_Mellilia.index, df_Mellilia['TAVG_MA30'], label='30-day Moving Average', linestyle='--')
plt.title('Temperature Trend')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# SARIMA model for temperature prediction
sarima_model = SARIMAX(df_Mellilia['TAVG'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)
forecast = sarima_fit.forecast(steps=1000)
plt.plot(df_Mellilia.index, df_Mellilia['TAVG'], label='Observed')
plt.plot(forecast.index, forecast, label='Forecast')
plt.title('SARIMA Forecast')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd

# Assuming 'df_Mellilia' has 'TAVG' and a datetime index
# SARIMA model for temperature prediction
sarima_model = SARIMAX(df_Mellilia['TAVG'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)

# Forecast 30 future steps
forecast_steps = 30
forecast = sarima_fit.forecast(steps=forecast_steps)

# Generate future dates based on the last date in the dataset
last_date = df_Mellilia.index[-1]
forecast_index = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=forecast_steps, freq='D')

# Plot the results
plt.figure(figsize=(10, 5))
plt.plot(df_Mellilia.index, df_Mellilia['TAVG'], label='Observed', color='blue')
plt.plot(forecast_index, forecast, label='Forecast', color='orange')
plt.title('SARIMA Forecast for TAVG')
plt.xlabel('Date')
plt.ylabel('Temperature (TAVG)')
plt.legend()
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Define features and target
features = df_Mellilia[['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG_MA7', 'TAVG_MA30', 'month', 'season']]
target = df_Mellilia['TAVG']

# Split data
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Train Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict and evaluate
y_pred = rf_model.predict(X_test)
print(f"MAE: {mean_absolute_error(y_test, y_pred):.2f}")
# Out:
# MAE: 0.04

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calculate MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Square Error: {rmse:.2f}")
# Out:
# Mean Absolute Error: 0.04
# Root Mean Square Error: 0.05
